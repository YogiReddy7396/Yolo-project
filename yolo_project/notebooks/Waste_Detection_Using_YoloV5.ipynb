# %% [markdown]
# # Waste Detection Inference
#
# Use this notebook to test the trained model on custom images.

# %%
import torch
import matplotlib.pyplot as plt

# Load Model
model_path = '../../web_app/backend/best.pt'
try:
    model = torch.hub.load('ultralytics/yolov5', 'custom', path=model_path, force_reload=True)
    print("Model loaded successfully.")
except Exception as e:
    print(f"Error loading model: {e}")
    print("Make sure you have run model_training.ipynb first!")

# %%
# Run Inference (Example)
# img = 'path/to/image.jpg'
# results = model(img)
# results.show()
