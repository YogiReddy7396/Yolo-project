# %%
import torch
print(torch.backends.mps.is_available())
# Out:
# True

# %%
import sys, torch

print("Python executable:")
print(sys.executable)

print("\nTorch location:")
print(torch.__file__)
# Out:
# Python executable:
# /Users/chintubharath/miniforge3/envs/torch-mps/bin/python
#
# Torch location:
# /Users/chintubharath/miniforge3/envs/torch-mps/lib/python3.10/site-packages/torch/__init__.py

# %%
pwd
# Out:
# '/Users/chintubharath/Downloads/garbage project test'

# %%
import torch

print("PyTorch version:", torch.__version__)
print("MPS built:", torch.backends.mps.is_built())
print("MPS available:", torch.backends.mps.is_available())

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print("Using device:", device)
# Out:
# PyTorch version: 2.5.1
# MPS built: True
# MPS available: True
# Using device: mps

# %%
import torch

# Set the device
device = "mps" if torch.backends.mps.is_available() else "cpu"

# Create data and send it to the device
x = torch.rand(size=(3, 4)).to(device)
x
# Out:
# tensor([[0.4943, 0.6164, 0.9874, 0.3725],
#         [0.4675, 0.1339, 0.5902, 0.1436],
#         [0.9147, 0.7005, 0.0769, 0.7528]], device='mps:0')
