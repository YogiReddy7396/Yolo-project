# %%
pip install ultralytics streamlit
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.5-py3-none-any.whl.metadata (38 kB)
# Collecting streamlit
#   Downloading streamlit-1.40.1-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: numpy>=1.23.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from ultralytics) (1.23.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from ultralytics) (3.7.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from ultralytics) (1.10.1)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.4.1-cp38-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.19.1-cp38-cp38-macosx_11_0_arm64.whl.metadata (6.0 kB)
# Requirement already satisfied: psutil>=5.8.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from ultralytics) (5.9.8)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.8.2-cp38-abi3-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: packaging<25,>=20 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from streamlit) (24.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: protobuf<6,>=3.20 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from streamlit) (4.25.3)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-17.0.0-cp38-cp38-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from streamlit) (4.5.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.46-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from streamlit) (6.4)
# Requirement already satisfied: jinja2 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit) (4.22.0)
# Collecting narwhals>=1.5.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.42.1-py3-none-any.whl.metadata (11 kB)
# Collecting typing-extensions<5,>=4.3.0 (from streamlit)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (2024.7.4)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting sympy (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Using cached networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in /Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.8.0->ultralytics)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading ultralytics-8.4.5-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.0 MB/s eta 0:00:00a 0:00:01
# Downloading streamlit-1.40.1-py2.py3-none-any.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 14.5 MB/s eta 0:00:00a 0:00:01
# Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 13.7 MB/s eta 0:00:00a 0:00:01
# Downloading gitpython-3.1.46-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.6/208.6 kB 11.2 MB/s eta 0:00:00
# Downloading polars-1.8.2-cp38-abi3-macosx_11_0_arm64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 2.5 MB/s eta 0:00:0000:0100:01
# Downloading pyarrow-17.0.0-cp38-cp38-macosx_11_0_arm64.whl (27.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 3.8 MB/s eta 0:00:0000:0100:01
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 9.7 MB/s eta 0:00:0000:0100:01
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 9.0 MB/s eta 0:00:00
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading torch-2.4.1-cp38-none-macosx_11_0_arm64.whl (62.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 MB 5.3 MB/s eta 0:00:0000:0100:01m
# Downloading torchvision-0.19.1-cp38-cp38-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.4 MB/s eta 0:00:0000:0100:01
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.0 MB/s eta 0:00:00
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading narwhals-1.42.1-py3-none-any.whl (359 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.9/359.9 kB 5.8 MB/s eta 0:00:00a 0:00:01
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 4.8 MB/s eta 0:00:00a 0:00:01
# Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 8.2 MB/s eta 0:00:0000:0100:01
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: mpmath, typing-extensions, toml, tenacity, sympy, smmap, pyarrow, polars, networkx, narwhals, mdurl, fsspec, filelock, torch, pydeck, markdown-it-py, gitdb, ultralytics-thop, torchvision, rich, gitpython, ultralytics, altair, streamlit
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-macos 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.13.2 which is incompatible.
# Successfully installed altair-5.4.1 filelock-3.16.1 fsspec-2025.3.0 gitdb-4.0.12 gitpython-3.1.46 markdown-it-py-3.0.0 mdurl-0.1.2 mpmath-1.3.0 narwhals-1.42.1 networkx-3.1 polars-1.8.2 pyarrow-17.0.0 pydeck-0.9.1 rich-13.9.4 smmap-5.0.2 streamlit-1.40.1 sympy-1.13.3 tenacity-9.0.0 toml-0.10.2 torch-2.4.1 torchvision-0.19.1 typing-extensions-4.13.2 ultralytics-8.4.5 ultralytics-thop-2.0.18
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install

# %%
import streamlit as st
from ultralytics import YOLO
from PIL import Image
import numpy as np

# 1. Load the Model
# Replace 'yolov8n.pt' with the path to your specific garbage detection model
# e.g., model = YOLO('best_garbage_model.pt')
try:
    model = YOLO('garbage_model.pt') 
except Exception as e:
    st.error(f"Error loading model: {e}")

st.title("🗑️ AI Garbage Detector")
st.write("Upload an image to detect waste categories.")

# 2. Image Upload Widget
uploaded_file = st.file_uploader("Choose an image...", type=["jpg", "jpeg", "png"])

if uploaded_file is not None:
    # Display original image
    image = Image.open(uploaded_file)
    st.image(image, caption='Uploaded Image', use_container_width=True)
    
    st.write("Detecting...")
    
    # 3. Perform Inference
    # conf=0.25 sets the sensitivity threshold
    results = model.predict(image, conf=0.25)

    # 4. Draw Boundary Boxes
    # result.plot() creates a new image array with the boxes drawn
    res_plotted = results[0].plot()
    
    # Convert back to PIL Image for display in Streamlit
    res_image = Image.fromarray(res_plotted[..., ::-1]) # RGB conversion
    
    st.success("Detection Complete!")
    st.image(res_image, caption='Detected Waste', use_container_width=True)

    # Optional: List detected categories
    st.write("### Detected Objects:")
    boxes = results[0].boxes
    for box in boxes:
        cls = int(box.cls[0])
        conf = float(box.conf[0])
        name = model.names[cls]
        st.write(f"- **{name}** (Confidence: {conf:.2f})")
# Out:
# OpenCV bindings requires "numpy" package.
# Install it via command:
#     pip install numpy
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/tensorflow-metal/env/lib/python3.8/site-packages/numpy/core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/tensorflow-metal/env/lib/python3.8/site-packages/numpy/core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/tensorflow-metal/env/lib/python3.8/site-packages/numpy/core/overrides.py:6
#       4 import os
# ----> 6 from numpy.core._multiarray_umath import (
#       7     add_docstring, implement_array_function, _get_implementing_args)
#       8 from numpy.compat._inspect import getargspec
#
# ImportError: dlopen(/Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages/numpy/core/_multiarray_umath.cpython-38-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <D37BED4E-7F75-3467-A281-7E7E316989C9> /Users/chintubharath/tensorflow-metal/env/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/chintubharath/tensorflow-metal/env/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/chintubharath/tensorflow-metal/env/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages/numpy/core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages/numpy/core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/chintubharath/tensorflow-metal/env/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/chintubharath/tensorflow-metal/env/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 import streamlit as st
# ----> 2 from ultralytics import YOLO
#       3 from PIL import Image
#       4 import numpy as np
#
# File ~/tensorflow-metal/env/lib/python3.8/site-packages/ultralytics/__init__.py:13
#      10 if not os.environ.get("OMP_NUM_THREADS"):
#      11     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
# ---> 13 from ultralytics.utils import ASSETS, SETTINGS
#      14 from ultralytics.utils.checks import check_yolo as checks
#      15 from ultralytics.utils.downloads import download
#
# File ~/tensorflow-metal/env/lib/python3.8/site-packages/ultralytics/utils/__init__.py:24
#      21 from types import SimpleNamespace
#      22 from urllib.parse import unquote
# ---> 24 import cv2
#      25 import numpy as np
#      26 import torch
#
# File ~/tensorflow-metal/env/lib/python3.8/site-packages/cv2/__init__.py:11
#       8 __all__ = []
#      10 try:
# ---> 11     import numpy
#      12     import numpy.core.multiarray
#      13 except ImportError:
#
# File ~/tensorflow-metal/env/lib/python3.8/site-packages/numpy/__init__.py:140
#     137 # Allow distributors to run custom init code
#     138 from . import _distributor_init
# --> 140 from . import core
#     141 from .core import *
#     142 from . import compat
#
# File ~/tensorflow-metal/env/lib/python3.8/site-packages/numpy/core/__init__.py:49
#      25     import sys
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#      51     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.8 from "/Users/chintubharath/tensorflow-metal/env/bin/python"
#   * The NumPy version is: "1.23.2"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages/numpy/core/_multiarray_umath.cpython-38-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <D37BED4E-7F75-3467-A281-7E7E316989C9> /Users/chintubharath/tensorflow-metal/env/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/chintubharath/tensorflow-metal/env/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/chintubharath/tensorflow-metal/env/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages/numpy/core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/chintubharath/tensorflow-metal/env/lib/python3.8/site-packages/numpy/core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/chintubharath/tensorflow-metal/env/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/chintubharath/tensorflow-metal/env/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
